# %% [markdown]
# # Contents
# > importing libraries and data
#
# > run describe and check for rows with 99999.000000
#
# > define and add price_range flag
#
# > Run loc on entire dataframe
#
# > Use a for-loop on dataframe
#
# > define and add 'busiest_days' column
#
# > identify busiest hours of the day
#
# > define and add busiest_period_of_day column
#
# > export data

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import Data

# %%
path = r'/Users/vanessalimsingh/Instacart Basket Analysis 07-05-2024'

# %%
df=pd.read_pickle(os.path.join(path,'02 Data','Prepared Data', 'ords_prods_merge.pkl'))

# %%
df.shape
# Out:
# (32404859, 18)

# %%
df = df[:1000000]

# %%
df.shape
# Out:
# (1000000, 18)

# %%
df.describe(include='all')['prices']
# Out:
# count     1000000.000000
# unique               NaN
# top                  NaN
# freq                 NaN
# mean           11.396794
# std           425.994349
# min             1.000000
# 25%             4.200000
# 50%             7.400000
# 75%            11.300000
# max         99999.000000
# Name: prices, dtype: float64

# %%
rows_with_99999 = df[df['prices'] == 99999]

# %%
print(rows_with_99999)
# Out:
#         Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  \
# 128911         13992         13992         13992    183964      873
# 128924         13993         13993         13993   1851256      873
# 284218         30778         30778         30778   1915696     1893
# 284229         30779         30779         30779   2763293     1893
# 284252         30781         30781         30781   2564805     1893
# 499076         53605         53605         53605    949012     3339
# 499119         53606         53606         53606    420057     3339
# 499141         53607         53607         53607   1511997     3339
# 499158         53608         53608         53608   1153448     3339
# 499180         53609         53609         53609   2669259     3339
# 527458         57126         57126         57126    965345     3531
# 767471         82423         82423         82423   2291230     5034
# 767485         82424         82424         82424   2324832     5034
# ...

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)

# %%
#Once the price_label function has been applied, run the value_counts() function to check the values in your new column.

df['price_range'].value_counts()
# Out:
# price_range
# Mid-range product    673183
# Low-range product    314392
# High range            12425
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (1000000, 19)

# %%
df['prices'].max()
# Out:
# 99999.0

# %%
def price_label(row):
    if row['prices'] <= 5:
        return 'Low-range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid-range product'
    elif row['prices'] > 15 and row['prices'] <= 16:
        return 'High-range product'
    elif row['prices'] >= 17:
        return 'others'
    else:
        return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts()
# Out:
# price_range
# Mid-range product     673183
# Low-range product     314392
# others                 10838
# High-range product       834
# Not enough data          753
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (1000000, 19)

# %%
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0             0   2539329        1             1
# 1             0             0             0   2539329        1             1
# 2             0             0             0   2539329        1             1
# 3             0             0             0   2539329        1             1
# 4             0             0             0   2539329        1             1
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  \
# 0          2                  8                     NaN         196
# 1          2                  8                     NaN       14084
# 2          2                  8                     NaN       12427
# 3          2                  8                     NaN       26088
# 4          2                  8                     NaN       26405
#
#    add_to_cart_order  reordered  Unnamed: 0_y  \
# ...

# %%
df['prices'].max()
# Out:
# 99999.0

# %% [markdown]
# # Max value for prices doesn't look right. Should this be removed?

# %% [markdown]
# # Using loc

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'] = df.apply(price_label, axis=1)

# %%
price_range_counts = df['price_range_loc'].value_counts()

# %%
print (price_range_counts)
# Out:
# price_range_loc
# Mid-range product     673183
# Low-range product     314392
# others                 10838
# High-range product       834
# Not enough data          753
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0             0   2539329        1             1
# 1             0             0             0   2539329        1             1
# 2             0             0             0   2539329        1             1
# 3             0             0             0   2539329        1             1
# 4             0             0             0   2539329        1             1
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  \
# 0          2                  8                     NaN         196
# 1          2                  8                     NaN       14084
# 2          2                  8                     NaN       12427
# 3          2                  8                     NaN       26088
# 4          2                  8                     NaN       26405
#
#    add_to_cart_order  reordered  Unnamed: 0_y  \
# ...

# %% [markdown]
# # Run loc on entire dataframe

# %%
df_opm=pd.read_pickle(os.path.join(path,'02 Data','Prepared Data', 'ords_prods_merge.pkl'))

# %%
df_opm.shape
# Out:
# (32404859, 18)

# %%
df_opm.loc[df_opm['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_opm.loc[(df_opm['prices'] <= 15) & (df_opm['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_opm.loc[df_opm['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_opm.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0             0   2539329        1             1
# 1             0             0             0   2539329        1             1
# 2             0             0             0   2539329        1             1
# 3             0             0             0   2539329        1             1
# 4             0             0             0   2539329        1             1
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  \
# 0          2                  8                     NaN         196
# 1          2                  8                     NaN       14084
# 2          2                  8                     NaN       12427
# 3          2                  8                     NaN       26088
# 4          2                  8                     NaN       26405
#
#    add_to_cart_order  reordered  Unnamed: 0_y  \
# ...

# %%
df_opm['price_range_loc'].value_counts()
# Out:
# price_range_loc
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: count, dtype: int64

# %% [markdown]
# # Use a for-loop in your Instacart dataframe

# %%
#print the frequency of the “orders_day_of_week” column

# %%
df_opm['order_dow'].value_counts(dropna=False)
# Out:
# order_dow
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
#the value 0 means Saturday

# %%
#0 means Saturday. This value has the highest frequency, meaning Saturday is the busiest day. Meanwhile, the 
#4 value has the lowest frequency. A value of 4, here, refers to Wednesday, meaning Wednesday is the 
#slowest day for Instacart app orders.
#You want to use this information to create a new column, “busiest day,” 
#that will contain one of three different values: “Busiest day,” “Least busy,” and “Regularly busy.” 
#This can be done using a for-loop. The loop will run through every row in the “orders_day_of_week” column, 
#compare its value with what you know are the busiest and slowest days, and assign it the corresponding 
#string value

# %%
result = []

for value in df_opm["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
#print the result
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
#add the new column to df_opm
df_opm['busiest_day']=result

# %%
#check if values correspond
df_opm['busiest_day'].value_counts(dropna=False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %%
df_opm['order_dow'].value_counts()
# Out:
# order_dow
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
df_opm.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0             0   2539329        1             1
# 1             0             0             0   2539329        1             1
# 2             0             0             0   2539329        1             1
# 3             0             0             0   2539329        1             1
# 4             0             0             0   2539329        1             1
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  \
# 0          2                  8                     NaN         196
# 1          2                  8                     NaN       14084
# 2          2                  8                     NaN       12427
# 3          2                  8                     NaN       26088
# 4          2                  8                     NaN       26405
#
#    add_to_cart_order  reordered  Unnamed: 0_y  \
# ...

# %%
#export to pickle
df_opm.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined_newcols.pkl'))

# %% [markdown]
# # Task work. Step 2

# %%
# Now, they want “Busiest day” to become “Busiest days” (plural). 
#This label should correspond with the two busiest days of the week as opposed to the single busiest day
#At the same time, they’d also like to know the two slowest days. 
#Create a new column for this using a suitable method.

# %%
#sort order_dow from biggest to smallest
df_opm['order_dow'].value_counts().sort_values(ascending=False)
# Out:
# order_dow
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
result = []

for value in df_opm["order_dow"]:
  if value in (0, 1):
    result.append("Busiest days")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Least busy',
#  'Least busy',
# ...

# %%
#add the new column to df_opm
df_opm['busiest_days']=result

# %% [markdown]
# # The new column 'busiest_days' have been added, which refers to the top two busiest days: Saturday and Sunday.
# > the previously defined column for busiest_day has been renamed to prior_busiest_day for now.

# %%
df_opm.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0             0   2539329        1             1
# 1             0             0             0   2539329        1             1
# 2             0             0             0   2539329        1             1
# 3             0             0             0   2539329        1             1
# 4             0             0             0   2539329        1             1
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  ...  \
# 0          2                  8                     NaN         196  ...
# 1          2                  8                     NaN       14084  ...
# 2          2                  8                     NaN       12427  ...
# 3          2                  8                     NaN       26088  ...
# 4          2                  8                     NaN       26405  ...
#
# ...

# %%
df_opm.rename(columns={'busiest_day': 'prior_busiest_day'}, inplace=True)

# %%
#sort order_dow from biggest to smallest
df_opm['order_dow'].value_counts().sort_values(ascending=False)
# Out:
# order_dow
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %% [markdown]
# # The two slowest days are '3' and '4' i.e. Tuesday and Wednesday

# %%
#Check consistency
df_opm['busiest_days'].value_counts(dropna=False)
# Out:
# busiest_days
# Regularly busy    16756645
# Busiest days      11864412
# Least busy         3783802
# Name: count, dtype: int64

# %% [markdown]
# # 3. The data in the new column is consistent.

# %% [markdown]
# # 4. Busiest hours of the day

# %%
#The senior technical officer at Instacart wants you to identify the busiest hours of the day.

# %%
#Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” 
#Create a new column containing these labels called “busiest_period_of_day.”

# %%
df_opm.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0             0   2539329        1             1
# 1             0             0             0   2539329        1             1
# 2             0             0             0   2539329        1             1
# 3             0             0             0   2539329        1             1
# 4             0             0             0   2539329        1             1
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  ...  \
# 0          2                  8                     NaN         196  ...
# 1          2                  8                     NaN       14084  ...
# 2          2                  8                     NaN       12427  ...
# 3          2                  8                     NaN       26088  ...
# 4          2                  8                     NaN       26405  ...
#
# ...

# %%
#sort Hour of day from biggest to smallest 
df_opm['order_hour_of_day'].value_counts().sort_values(ascending=True)
# Out:
# order_hour_of_day
# 3       51281
# 4       53242
# 2       69375
# 5       87961
# 1      115700
# 0      218769
# 6      290493
# 23     402316
# 22     634225
# 21     795637
# 7      891054
# 20     976156
# 19    1258305
# 18    1636502
# 8     1718118
# 17    2087654
# 9     2454203
# 16    2535202
# 12    2618532
# 13    2660954
# 15    2662144
# 14    2689136
# 11    2736140
# 10    2761760
# Name: count, dtype: int64

# %%
hour_of_day_counts = df_opm['order_hour_of_day'].value_counts()

# %%
hour_of_day_counts
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
# most orders = 10, 11, 14, 15, 13, 12, 16, 9
# Average orders = 22-17
# fewest orders = 3, 4, 2,5,1,0,6,23

# %%
result2 = []

for value in df_opm["order_hour_of_day"]:
  if value in (10, 11, 14, 15, 13, 12, 16, 9):
    result2.append("Most orders")
  elif value in (3, 4, 2,5,1,0,6,23):
    result2.append("fewest orders")
  else:
    result2.append("Average orders")

# %%
result2
# Out:
# ['Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
# ...

# %%
df_opm['order_rate']=result2

# %%
df_opm.rename(columns={'order_rate': 'busiest_period_of_day'}, inplace=True)

# %%
df_opm.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0             0   2539329        1             1
# 1             0             0             0   2539329        1             1
# 2             0             0             0   2539329        1             1
# 3             0             0             0   2539329        1             1
# 4             0             0             0   2539329        1             1
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  ...  \
# 0          2                  8                     NaN         196  ...
# 1          2                  8                     NaN       14084  ...
# 2          2                  8                     NaN       12427  ...
# 3          2                  8                     NaN       26088  ...
# 4          2                  8                     NaN       26405  ...
#
# ...

# %%
#check if values correspond
order_rate_counts = df_opm['busiest_period_of_day'].value_counts(dropna=False)

# %%
order_rate_counts
# Out:
# busiest_period_of_day
# Most orders       21118071
# Average orders     9997651
# fewest orders      1289137
# Name: count, dtype: int64

# %%
order_rate_counts.sum()
# Out:
# 32404859

# %%
hour_of_day_counts.sum()
# Out:
# 32404859

# %% [markdown]
# # A new column 'busiest_period_of_day' was created above.
# > this is how they are categorised:
#
# > Most orders = 10, 11, 14, 15, 13, 12, 16, 9
#
# > Average orders = 22-17
#
# > fewest orders = 3, 4, 2,5,1,0,6,23

# %% [markdown]
# # 5. Print frequency of busiest_period_of_day

# %%
#print frequency of busiest_period_of_day
df_opm['busiest_period_of_day'].value_counts(dropna=False)
# Out:
# busiest_period_of_day
# Most orders       21118071
# Average orders     9997651
# fewest orders      1289137
# Name: count, dtype: int64

# %%
df_opm.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge_version2.pkl'))
